# %%
import pandas as pd

# %%
df =  pd.read_csv("telecom_churn.csv")

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[df['Churn']==True]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['Churn']==True) & (df['Area code']==510)]['Churn'].value_counts()
# Out:
# Churn
# True    125
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
columns_to_show = ['Total day minutes','Total eve minutes']

# %%
df.groupby('Churn')[columns_to_show].mean()
# Out:
#        Total day minutes  Total eve minutes
# Churn
# False         175.175754         199.043298
# True          206.914079         212.410145

# %%
df_emp = pd.read_csv('employees.csv')

# %%
df_emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
feature_list = df_emp.columns

# %%
feature_list
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df_emp['Gender'].describe(include = all)
# Out:
# count        855
# unique         2
# top       Female
# freq         431
# Name: Gender, dtype: object

# %%
df_emp.isnull().count()
# Out:
# First Name           1000
# Gender               1000
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management    1000
# Team                 1000
# dtype: int64

# %%
df_emp['Team'].value_counts()
# Out:
# Team
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: count, dtype: int64

# %%
df_emp.groupby('Salary')['Last Login Time'].max()
# Out:
# Salary
# 35013      5:35 PM
# 35061      7:31 AM
# 35095      9:20 PM
# 35203     10:33 PM
# 35381      1:24 AM
#             ...
# 149563     7:26 PM
# 149654     9:50 PM
# 149684     8:55 AM
# 149903     8:40 AM
# 149908    12:21 AM
# Name: Last Login Time, Length: 995, dtype: object

# %%
df_emp[df_emp['Salary']==df_emp['Salary'].max()]['Last Login Time']
# Out:
# 644    12:21 AM
# Name: Last Login Time, dtype: object

# %%
df_emp[df_emp['Bonus %']==df_emp['Bonus %'].min()]['First Name']
# Out:
# 217    Douglas
# Name: First Name, dtype: object
